# %%
import random
import itertools
import glob
import numpy as np
import sparse
from tqdm import tqdm
from PIL import Image
import torch

import matplotlib.pyplot as plt

# %%
def create_voxel_grid(cif_file,voxel_count, max_dims, atoms_used=['Ce','O']):
    '''
    Voxelize the a single .cif file. Automatically detects which of 2 .cif file formats is used.
    Inputs:
    cif_file - str, path to .cif file
    voxel_count - list [x,y,z] or scalar if all same, number of voxels per side.
    max_dims - list [x,y,z] of max dimensions across structures. Used to set appropriate
               grid depth in z dimension, which varies across structures.
    atoms_used - list, indicates which atoms to include 
    
    Outputs:
    grid - 3D numpy array [voxel_size_x,voxel_size_y,voxel_size_z] 
           where values indicate number of atoms centered in the voxel
    coor - numpy array [n_atoms,3] of coordinates of each atom
    atom_type numpy array [n_atoms] of atom type
    
    NOTE: coor and atom_type include all atoms, not just those in atoms_used.
    '''
    # Read the .cif file
    f = open(cif_file)
    y = f.readlines()

    # Box dimensions
    # Extract '_cell_length_c' from .cif file. This length varies for each structure.
    increm = 0
    # try-except accounts for new .cif format where cell lengths start on line 3
    try:
        x_dim = float(y[2].split('  ')[-1])
    except ValueError:
        increm = 1
        x_dim = float(y[2+increm].split('  ')[-1])
    y_dim = float(y[3+increm].split('  ')[-1])
    z_dim = float(y[4+increm].split('  ')[-1])

    # Extract the atom locations
    if len(y[15].split("  ")) < 4:

        # for .cif files from ASU_April_21
        if len(y[23].split("  ")) < 4:
            z=np.array([x.split("  ") for x in y[26:]])
            coor = np.array([[float(y) for y in x] for x in z[:,4:7]])
            atom_type = np.array([x.split(" ")[0] for x in z[:,1]])

        # for .cif files from models_wedge_cif and models_wedge_cif_2
        else:
            z=np.array([x.split("  ") for x in y[23:-1]])
            coor = np.array([[float(y) for y in x] for x in z[:,2:5]])
            atom_type = np.array([x.split(" ")[0] for x in z[:,1]])

    # for .cif files from models_cif
    elif len(y[15].split("  ")) == 4:
        z = np.array([x.split("  ") for x in y[15:]]) 
        coor = np.array([[float(y) for y in x] for x in z[:,1:]]) 
        atom_type = z[:,0]

    # Voxelize
    # .cif describes a 1x1x1 box, so voxel_count of 0.25 would create 4 voxels per dimension (4^3 total voxels)
    if type(voxel_count) == list:
        voxel_count_x,voxel_count_y,voxel_count_z = voxel_count
    elif (type(voxel_count) == int) or (type(voxel_count) == float):
        voxel_count_x = voxel_count
        voxel_count_y = voxel_count
        voxel_count_z = voxel_count
        
    # grid has number of channels equal to number of atom types in lattice
    num_atoms = len(atoms_used)
    atom_mapping = {at:i for i,at in enumerate(atoms_used)}
    grid = np.zeros([voxel_count_x,voxel_count_y,voxel_count_z,num_atoms])

    # Normalize coor for axis lengths
    coor = coor*np.array([x_dim,y_dim,z_dim])/np.array(max_dims)
    
    for i,atom in enumerate(coor):
        if atom_type[i] in atoms_used:
            x = int(np.floor(atom[0]*voxel_count_x))
            y = int(np.floor(atom[1]*voxel_count_y))
            z = int(np.floor(atom[2]*voxel_count_z))
            grid[x,y,z,atom_mapping[atom_type[i]]] += 1
    grid = sparse.COO.from_numpy(grid)
    return grid, coor, atom_type

# Determine max z length
def max_z_value(dir_header, dir_list_cif):

    cif_files = []

    for dirr in dir_list_cif:
        cif_files.extend(glob.glob(dir_header+dirr+'/Ce*.cif'))

    x_list,y_list,z_list = [],[],[]

    for cf in cif_files:
        f = open(cf)
        y = f.readlines()
        # increm accounts for new format .cif files
        increm = 0
        try:
            x_list.append(float(y[2].split('  ')[-1]))
        except ValueError:
            increm = 1
            x_list.append(float(y[2+increm].split('  ')[-1]))
        y_list.append(float(y[3+increm].split('  ')[-1]))
        z_list.append(float(y[4+increm].split('  ')[-1]))

    return [np.max(x_list),np.max(y_list),np.max(z_list)]

# %%
def generate_training_data(dir_header, dir_list_cif, dir_list_img, voxel_count, 
                           atoms_used, defocus_in, im_size = 256):
    '''
    Generates pairs of voxel grid (X) and image (y) as well as defocus parameter and filenames, for training
    3D grid -> image model.
    
    Inputs:
    dir_list_cif - list of directories containing .cif files, relative path from current directory
    dir_list_img - list of directories containing .yif files, relative path from current directory
    voxel_count - scalar int indicating desired voxels per grid dimension
    atoms_used - List of strings indicating which atom types (e.g. ['O', 'Ce']) to include. 
    defocus_used - List of ints indicating which defocus values to include. If set to 1, all values are used.
    im_size - 2-tuple of ints indicating desired pixels per image dimension (X,Y)
    
    Outputs:
    X_list - List of [grid, atom_type] lists for each .cif-.tif pair used. 
              grid is a [voxel_size^3] np.array with counts of atoms in each voxel
              atom_type is a np.array of strings for each atom's periodic symbol
                
    y_list - List of images, one for each entry in X_list. image is a [im_size[0],im_size[1]] np.array of pixel values.
              image created by cropping input to square then resizing to im_size in PIL.
    defocus_list - List of ints, defocus parameter for each sample 
    img_file_list - List of image filenames for each sample.
    
    '''
    # Calculate largest z value
    max_dims = max_z_value(dir_header,dir_list_cif)
    
    cif_files = []
    for dirr in dir_list_cif:
        cif_files.extend(glob.glob(dir_header+dirr+'/Ce*.cif'))


    X_list = []
    y_list = []
    defocus_list = []
    img_file_list = []

    for k,cif in enumerate(cif_files):
        # Create voxel grid from .cif file 
        X, coor, atom_type = create_voxel_grid(cif,voxel_count, max_dims, atoms_used=atoms_used)

        # Find all associated images
        img_files = []
        if cif.find("CIF") < 0:
            [img_files.extend(glob.glob((dir_header+dirr+cif[cif.find("/",len(dir_header)+3):-4]+'*.tif').replace('[','?').replace(']','?'))) for dirr in dir_list_img]
        else:
            [img_files.extend(glob.glob((dir_header+dirr+cif[cif.find("/",len(dir_header)+len(dirr)+3):-4]+'*.tif').replace('[','?').replace(']','?'))) for dirr in dir_list_img]
        # find starts after the dir_header so it catches the last /
        # Filter out 'def' files
        img_files_clean = []
        for i,im_f in enumerate(img_files):
            if im_f.find("_def_") < 0:
                img_files_clean.append(im_f)
        img_files = img_files_clean        
        # Filter by Defocus value
        nm_loc = [im_f.find("nmDefocus") for im_f in img_files]
        
#         defocus_cif = [abs(int(im_f[loc-2:loc])) for im_f,loc in zip(img_files,nm_loc)]

        defocus_cif = []
        for im_f,loc in zip(img_files,nm_loc):
            if im_f[loc-2:loc-1] == '_':
                defocus_cif.append(abs(int(im_f[loc-1:loc])))
            else:
                defocus_cif.append(abs(int(im_f[loc-2:loc])))
            
    
        if defocus_in == 1:
            defocus_used = set(defocus_cif)
        else:
            defocus_used = defocus_in

        #X_count counts the number of images for each .cif file, to replicate the voxel that many times
        X_count = 0
        # Collect image data
        for defoc,image in zip(defocus_cif,img_files):
            if defoc in defocus_used:
                X_count +=1
                im_data=np.array(Image.open(image).resize((im_size[0],im_size[1])))
                y_list.append(im_data)
                defocus_list.append(defoc)
                img_file_list.append(image)    

        # Make training pairs for each defocus value in defocus_used
        X_list.extend(itertools.repeat(X,X_count)) # Probably move this so it can be repeated for various defocus values
        print("Images to cif {}: {}\t{} ".format(k,X_count,cif))
    return X_list, y_list, defocus_list, img_file_list

# %%
# Inputs
# dir_header = '../../em_data/'
# dir_list_cif = ['models_cif','models_wedge_cif','models_wedge_cif_2']
# dir_list_img = ['all_images','all_images_wedge','all_images_wedge_2']

dir_header = 'em_data/'
dir_list_cif = ['models_cif','models_wedge_cif','models_wedge_cif_2',
                '1at/CIF','2at/CIF','2at_2/CIF','3at/CIF',
                '3at_2/CIF','4at/CIF','4at_2/CIF',
                '5at/CIF','5at_2/CIF','6at/CIF','6at_2/CIF','7at/CIF','7at_2/CIF','8at/CIF',
                '8at_2/CIF','9at/CIF','9at_2/CIF','10at/CIF','10at_2/CIF']
dir_list_img = ['all_images','all_images_wedge','all_images_wedge_2',
                '1at','2at','2at_2','3at',
                '3at_2','4at','4at_2','5at','5at_2','6at','6at_2',
                '7at','7at_2','8at','8at_2','9at','9at_2','10at','10at_2']

voxel_count = [84,54,98]
im_size = [84,54]
atoms_used=['Ce','O']
defocus_used = 1 # list defocus values to use, or set =1 to use all

# %%
cif = 'jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z.cif'
glob.glob((dir_header+'3at_2'+cif[cif.find("/",len(dir_header)+5):-4]+'*.tif').replace('[','?').replace(']','?'))
# Out:
# ['em_data/3at_2/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z_060slc_2048x2048_2nmDefocus.tif',
#  'em_data/3at_2/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z_060slc_2048x2048_8nmDefocus.tif',
#  'em_data/3at_2/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z_060slc_2048x2048_10nmDefocus.tif',
#  'em_data/3at_2/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z_060slc_2048x2048_6nmDefocus.tif',
#  'em_data/3at_2/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z_060slc_2048x2048_3nmDefocus.tif',
#  'em_data/3at_2/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z_060slc_2048x2048_7nmDefocus.tif',
#  'em_data/3at_2/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z_060slc_2048x2048_9nmDefocus.tif',
#  'em_data/3at_2/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z_060slc_2048x2048_5nmDefocus.tif',
#  'em_data/3at_2/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z_060slc_2048x2048_4nmDefocus.tif',
#  'em_data/3at_2/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z_060slc_2048x2048_1nmDefocus.tif']

# %%
img_files = []
[img_files.extend(glob.glob((dir_header+dirr+cif[cif.find("/",len(dir_header)+5):-4]+'*.tif').replace('[','?').replace(']','?'))) for dirr in dir_list_img]
# find starts after the dir_header so it catches the last /
# Filter out 'def' files
img_files_clean = []
for i,im_f in enumerate(img_files):
    if im_f.find("_def_") < 0:
        img_files_clean.append(im_f)
img_files = img_files_clean        
# Filter by Defocus value
img_files

# %%
nm_loc = [im_f.find("nmDefocus") for im_f in img_files]

#         defocus_cif = [abs(int(im_f[loc-2:loc])) for im_f,loc in zip(img_files,nm_loc)]
defocus_cif = []
for im_f,loc in zip(img_files,nm_loc):
    if im_f[loc-2:loc-1] == '_':
        defocus_cif.append(abs(int(im_f[loc-1:loc])))
    else:
        defocus_cif.append(abs(int(im_f[loc-2:loc])))

# %%
defocus_used = set(defocus_cif)

#X_count counts the number of images for each .cif file, to replicate the voxel that many times
X_count = 0
# Collect image data
for defoc,image in zip(defocus_cif,img_files):
    if defoc in defocus_used:
        X_count +=1
        im_data=np.array(Image.open(image).resize((im_size[0],im_size[1])))
#         y_list.append(im_data)
#         defocus_list.append(defoc)
#         img_file_list.append(image) 
X_count

# %%
'CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z'.find("_def_")

# %%
X_list, y_list, defocus_list, img_file_list = generate_training_data( \
                            dir_header, dir_list_cif, dir_list_img, voxel_count, atoms_used, defocus_used, im_size)
# Out:
# Images to cif 0: 11	em_data/models_cif/CeO2_011_100sur_8mu.cif
# Images to cif 1: 11	em_data/models_cif/CeO2_011_corner_3mu.cif
# Images to cif 2: 11	em_data/models_cif/CeO2_011_100sur_5mu.cif
# Images to cif 3: 11	em_data/models_cif/CeO2_011_111sur_10mu.cif
# Images to cif 4: 11	em_data/models_cif/CeO2_011_corner_7mu.cif
# Images to cif 5: 11	em_data/models_cif/CeO2_011_cornerb_2mu.cif
# Images to cif 6: 11	em_data/models_cif/CeO2_011_100sur_2mu.cif
# Images to cif 7: 11	em_data/models_cif/CeO2_011_corner_10mu.cif
# Images to cif 8: 11	em_data/models_cif/CeO2_011_111sur_4mu.cif
# Images to cif 9: 11	em_data/models_cif/CeO2_011_111sur_2mu.cif
# Images to cif 10: 11	em_data/models_cif/CeO2_011_100sur_4mu.cif
# Images to cif 11: 11	em_data/models_cif/CeO2_011_cornerb_4mu.cif
# Images to cif 12: 11	em_data/models_cif/CeO2_011_111sur_3mu.cif
# Images to cif 13: 11	em_data/models_cif/CeO2_011_100sur_6mu.cif
# Images to cif 14: 11	em_data/models_cif/CeO2_011_100sur_1mu.cif
# Images to cif 15: 11	em_data/models_cif/CeO2_011_100sur_9mu.cif
# Images to cif 16: 11	em_data/models_cif/CeO2_011_cornerb_8mu.cif
# Images to cif 17: 11	em_data/models_cif/CeO2_011_corner_9mu.cif
# Images to cif 18: 11	em_data/models_cif/CeO2_011_111sur_1mu.cif
# Images to cif 19: 11	em_data/models_cif/CeO2_011_cornerb_3mu.cif
# Images to cif 20: 11	em_data/models_cif/CeO2_011_cornerb_9mu.cif
# Images to cif 21: 11	em_data/models_cif/CeO2_011_corner_4mu.cif
# Images to cif 22: 11	em_data/models_cif/CeO2_011_111sur_8mu.cif
# Images to cif 23: 11	em_data/models_cif/CeO2_011_corner_5mu.cif
# Images to cif 24: 11	em_data/models_cif/CeO2_011_100sur_7mu.cif
# Images to cif 25: 11	em_data/models_cif/CeO2_011_111sur_5mu.cif
# Images to cif 26: 11	em_data/models_cif/CeO2_011_111sur_9mu.cif
# Images to cif 27: 11	em_data/models_cif/CeO2_011_corner_6mu.cif
# Images to cif 28: 11	em_data/models_cif/CeO2_011_cornerb_10mu.cif
# Images to cif 29: 11	em_data/models_cif/CeO2_011_cornerb_7mu.cif
# Images to cif 30: 11	em_data/models_cif/CeO2_011_100sur_10mu.cif
# Images to cif 31: 11	em_data/models_cif/CeO2_011_corner_1mu.cif
# Images to cif 32: 11	em_data/models_cif/CeO2_011_111sur_6mu.cif
# Images to cif 33: 11	em_data/models_cif/CeO2_011_cornerb_1mu.cif
# Images to cif 34: 11	em_data/models_cif/CeO2_011_111sur_7mu.cif
# Images to cif 35: 11	em_data/models_cif/CeO2_011_corner_2mu.cif
# Images to cif 36: 11	em_data/models_cif/CeO2_011_cornerb_6mu.cif
# Images to cif 37: 11	em_data/models_cif/CeO2_011_100sur_3mu.cif
# Images to cif 38: 11	em_data/models_cif/CeO2_011_cornerb_5mu.cif
# Images to cif 39: 11	em_data/models_cif/CeO2_011_corner_8mu.cif
# Images to cif 40: 6	em_data/models_wedge_cif/CeO2-wedge-struc1a.cif
# Images to cif 41: 10	em_data/models_wedge_cif/CeO2-wedge-struc5b.cif
# Images to cif 42: 0	em_data/models_wedge_cif/CeO2-wedge-struc4c.cif
# Images to cif 43: 0	em_data/models_wedge_cif/CeO2-wedge-struc2b_def.cif
# Images to cif 44: 11	em_data/models_wedge_cif/CeO2-wedge-struc4a.cif
# Images to cif 45: 8	em_data/models_wedge_cif/CeO2-wedge-struc3b.cif
# Images to cif 46: 0	em_data/models_wedge_cif/CeO2-wedge-struc3a_def.cif
# Images to cif 47: 7	em_data/models_wedge_cif/CeO2-wedge-struc1b.cif
# Images to cif 48: 0	em_data/models_wedge_cif/CeO2-wedge-struc3d_def.cif
# Images to cif 49: 0	em_data/models_wedge_cif/CeO2-wedge-struc1b_def.cif
# Images to cif 50: 0	em_data/models_wedge_cif/CeO2-wedge-struc3c_def.cif
# Images to cif 51: 5	em_data/models_wedge_cif/CeO2-wedge-struc3d.cif
# Images to cif 52: 0	em_data/models_wedge_cif/CeO2-wedge-struc5a_def.cif
# Images to cif 53: 12	em_data/models_wedge_cif/CeO2-wedge-struc2a.cif
# Images to cif 54: 0	em_data/models_wedge_cif/CeO2-wedge-struc3b_def.cif
# Images to cif 55: 9	em_data/models_wedge_cif/CeO2-wedge-struc3a.cif
# Images to cif 56: 0	em_data/models_wedge_cif/CeO2-wedge-struc3c.cif
# Images to cif 57: 0	em_data/models_wedge_cif/CeO2-wedge-struc5b_def.cif
# Images to cif 58: 0	em_data/models_wedge_cif/CeO2-wedge-struc4b_def.cif
# Images to cif 59: 0	em_data/models_wedge_cif/CeO2-wedge-struc4c_def.cif
# Images to cif 60: 4	em_data/models_wedge_cif/CeO2-wedge-struc4b.cif
# Images to cif 61: 0	em_data/models_wedge_cif/CeO2-wedge-struc1a_def.cif
# Images to cif 62: 6	em_data/models_wedge_cif/CeO2-wedge-struc2a-def.cif
# Images to cif 63: 7	em_data/models_wedge_cif/CeO2-wedge-struc2b.cif
# Images to cif 64: 0	em_data/models_wedge_cif/CeO2-wedge-struc4a_def.cif
# Images to cif 65: 6	em_data/models_wedge_cif/CeO2-wedge-struc5a.cif
# Images to cif 66: 0	em_data/models_wedge_cif_2/CeO2-wedge-struc10_def.cif
# Images to cif 67: 11	em_data/models_wedge_cif_2/CeO2-wedge-struc10.cif
# Images to cif 68: 0	em_data/models_wedge_cif_2/CeO2-wedge-struc7_def.cif
# Images to cif 69: 11	em_data/models_wedge_cif_2/CeO2-wedge-struc7.cif
# Images to cif 70: 11	em_data/models_wedge_cif_2/CeO2-wedge-struc9.cif
# Images to cif 71: 0	em_data/models_wedge_cif_2/CeO2-wedge-struc9_def.cif
# Images to cif 72: 0	em_data/models_wedge_cif_2/CeO2-wedge-struc6_def.cif
# Images to cif 73: 11	em_data/models_wedge_cif_2/CeO2-wedge-struc6.cif
# Images to cif 74: 11	em_data/models_wedge_cif_2/CeO2-wedge-struc11.cif
# Images to cif 75: 0	em_data/models_wedge_cif_2/CeO2-wedge-struc11_def.cif
# Images to cif 76: 11	em_data/models_wedge_cif_2/CeO2-wedge-struc8.cif
# Images to cif 77: 0	em_data/models_wedge_cif_2/CeO2-wedge-struc8_def.cif
# Images to cif 78: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-1def_expanded_000x000y000z.cif
# Images to cif 79: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-1def_expanded_-274x-176y000z.cif
# Images to cif 80: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_1-1def_expanded_-319x231y000z.cif
# Images to cif 81: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-1def_expanded_205x125y000z.cif
# Images to cif 82: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-0def_expanded_32x-369y000z.cif
# Images to cif 83: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-1def_expanded_-276x105y000z.cif
# Images to cif 84: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-1def_expanded_-274x105y000z.cif
# Images to cif 85: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_1-1def_expanded_000x000y000z.cif
# Images to cif 86: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_1-1def_expanded_262x305y000z.cif
# Images to cif 87: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-0def_expanded_029x-044y000z.cif
# Images to cif 88: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-0def_expanded_-109x-393y000z.cif
# Images to cif 89: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-1def_expanded_-112x15y000z.cif
# Images to cif 90: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_1-1def_expanded_-235x156y000z.cif
# Images to cif 91: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_1-1def_expanded_372x158y000z.cif
# Images to cif 92: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-1def_expanded_000x000y000z.cif
# Images to cif 93: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_1-1def_expanded_319x-123y000z.cif
# Images to cif 94: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-0def_expanded_-109x139y000z.cif
# Images to cif 95: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-1def_expanded_205x038y000z.cif
# Images to cif 96: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_1-1def_expanded_078x-394y000z.cif
# Images to cif 97: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_1-1def_expanded_078x-151y000z.cif
# Images to cif 98: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-0def_expanded_-241x351y000z.cif
# Images to cif 99: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-1def_expanded_-274x372y000z.cif
# Images to cif 100: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-1def_expanded_345x322y000z.cif
# Images to cif 101: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_1-1def_expanded_-336x-394y000z.cif
# Images to cif 102: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_1-1def_expanded_-235x158y000z.cif
# Images to cif 103: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-0def_expanded_-006x139y000z.cif
# Images to cif 104: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_1-1def_expanded_078x231y000z.cif
# Images to cif 105: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_1-1def_expanded_-235x335y000z.cif
# Images to cif 106: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-1def_expanded_205x322y000z.cif
# Images to cif 107: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_1-1def_expanded_-369x305y000z.cif
# Images to cif 108: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-0def_expanded_-31x295y000z.cif
# Images to cif 109: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-1def_expanded_000x000y000z.cif
# Images to cif 110: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_1-1def_expanded_262x-123y000z.cif
# Images to cif 111: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_1-1def_expanded_000x000y000z.cif
# Images to cif 112: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-0def_expanded_218x-393y000z.cif
# Images to cif 113: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_1-1def_expanded_-336x231y000z.cif
# Images to cif 114: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-1def_expanded_284x15y000z.cif
# Images to cif 115: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-0def_expanded_-241x-044y000z.cif
# Images to cif 116: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-1def_expanded_284x186y000z.cif
# Images to cif 117: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-1def_expanded_049x-338y000z.cif
# Images to cif 118: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-0def_expanded_218x-384y000z.cif
# Images to cif 119: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-1def_expanded_343x322y000z.cif
# Images to cif 120: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-0def_expanded_-271x-066y000z.cif
# Images to cif 121: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-1def_expanded_345x038y000z.cif
# Images to cif 122: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-0def_expanded_-006x-393y000z.cif
# Images to cif 123: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-0def_expanded_029x-066y000z.cif
# Images to cif 124: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_1-1def_expanded_000x000y000z.cif
# Images to cif 125: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_1-1def_expanded_-19x335y000z.cif
# Images to cif 126: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-1def_expanded_284x-338y000z.cif
# Images to cif 127: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-1def_expanded_049x15y000z.cif
# Images to cif 128: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-0def_expanded_-241x-066y000z.cif
# Images to cif 129: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-0def_expanded_000x000y000z.cif
# Images to cif 130: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-0def_expanded_-109x-384y000z.cif
# Images to cif 131: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-0def_expanded_218x139y000z.cif
# Images to cif 132: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-1def_expanded_085x105y000z.cif
# Images to cif 133: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_1-1def_expanded_319x212y000z.cif
# Images to cif 134: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-0def_expanded_000x000y000z.cif
# Images to cif 135: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-0def_expanded_-006x-384y000z.cif
# Images to cif 136: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-0def_expanded_-168x-369y000z.cif
# Images to cif 137: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-0def_expanded_029x351y000z.cif
# Images to cif 138: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-1def_expanded_085x-176y000z.cif
# Images to cif 139: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_1-1def_expanded_262x212y000z.cif
# Images to cif 140: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_1-1def_expanded_-319x-394y000z.cif
# Images to cif 141: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-0def_expanded_-271x-044y000z.cif
# Images to cif 142: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-0def_expanded_-31x-369y000z.cif
# Images to cif 143: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_1-1def_expanded_-319x-151y000z.cif
# Images to cif 144: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_1-1def_expanded_-369x212y000z.cif
# Images to cif 145: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_1-1def_expanded_319x305y000z.cif
# Images to cif 146: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_1-1def_expanded_372x335y000z.cif
# Images to cif 147: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-0def_expanded_-31x28y000z.cif
# Images to cif 148: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_1-1def_expanded_372x156y000z.cif
# Images to cif 149: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-0def_expanded_-168x28y000z.cif
# Images to cif 150: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-1def_expanded_343x038y000z.cif
# Images to cif 151: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_1-1def_expanded_-19x158y000z.cif
# Images to cif 152: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_1-1def_expanded_-19x156y000z.cif
# Images to cif 153: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-0def_expanded_32x28y000z.cif
# Images to cif 154: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-1def_expanded_345x125y000z.cif
# Images to cif 155: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-1def_expanded_343x125y000z.cif
# Images to cif 156: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-0def_expanded_000x000y000z.cif
# Images to cif 157: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-1def_expanded_085x372y000z.cif
# Images to cif 158: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-1def_expanded_049x186y000z.cif
# Images to cif 159: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-0def_expanded_32x295y000z.cif
# Images to cif 160: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_1-1def_expanded_-369x-123y000z.cif
# Images to cif 161: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-1def_expanded_-276x-176y000z.cif
# Images to cif 162: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-1def_expanded_-112x-338y000z.cif
# Images to cif 163: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-1def_expanded_-276x372y000z.cif
# Images to cif 164: 10	em_data/1at/CIF/CeO2_[110]_110sur_step_1mu_0-0def_expanded_-168x295y000z.cif
# Images to cif 165: 10	em_data/1at/CIF/CeO2_[110]_110sur_sawtooh_1mu_0-1def_expanded_-112x186y000z.cif
# Images to cif 166: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_1-1def_expanded_-336x-151y000z.cif
# Images to cif 167: 10	em_data/1at/CIF/CeO2_[110]_110sur_1mu_0-0def_expanded_-271x351y000z.cif
# Images to cif 168: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_16x228y000z.cif
# Images to cif 169: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-304x-39y000z.cif
# Images to cif 170: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-091x169y000z.cif
# Images to cif 171: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_07x158y000z.cif
# Images to cif 172: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_-019x167y000z.cif
# Images to cif 173: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_177x-242y000z.cif
# Images to cif 174: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_-072x-263y000z.cif
# Images to cif 175: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_388x018y000z.cif
# Images to cif 176: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-066x-006y000z.cif
# Images to cif 177: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_-019x228y000z.cif
# Images to cif 178: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-305x-198y000z.cif
# Images to cif 179: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-395x-006y000z.cif
# Images to cif 180: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_000x000y000z.cif
# Images to cif 181: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_007x-254y000z.cif
# Images to cif 182: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_007x12y000z.cif
# Images to cif 183: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_388x-38y000z.cif
# Images to cif 184: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_129x211y000z.cif
# Images to cif 185: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-028x-006y000z.cif
# Images to cif 186: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_023x-254y000z.cif
# Images to cif 187: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_000x000y000z.cif
# Images to cif 188: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_393x-109y000z.cif
# Images to cif 189: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_122x362y000z.cif
# Images to cif 190: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_291x226y000z.cif
# Images to cif 191: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_07x232y000z.cif
# Images to cif 192: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_209x211y000z.cif
# Images to cif 193: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_129x-201y000z.cif
# Images to cif 194: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_398x-043y000z.cif
# Images to cif 195: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_-072x-179y000z.cif
# Images to cif 196: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_363x-109y000z.cif
# Images to cif 197: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_078x-285y000z.cif
# Images to cif 198: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_-169x158y000z.cif
# Images to cif 199: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_331x228y000z.cif
# Images to cif 200: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-395x399y000z.cif
# Images to cif 201: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_177x-263y000z.cif
# Images to cif 202: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-052x-229y000z.cif
# Images to cif 203: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_-033x109y000z.cif
# Images to cif 204: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_281x-377y000z.cif
# Images to cif 205: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_209x-284y000z.cif
# Images to cif 206: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_16x167y000z.cif
# Images to cif 207: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_-033x018y000z.cif
# Images to cif 208: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_159x-284y000z.cif
# Images to cif 209: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_159x-201y000z.cif
# Images to cif 210: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_381x-263y000z.cif
# Images to cif 211: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-305x-39y000z.cif
# Images to cif 212: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_-39x396y000z.cif
# Images to cif 213: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_000x000y000z.cif
# Images to cif 214: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_023x362y000z.cif
# Images to cif 215: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_007x362y000z.cif
# Images to cif 216: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_363x031y000z.cif
# Images to cif 217: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_331x167y000z.cif
# Images to cif 218: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_07x-116y000z.cif
# Images to cif 219: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_078x226y000z.cif
# Images to cif 220: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_078x-043y000z.cif
# Images to cif 221: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_331x039y000z.cif
# Images to cif 222: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-02x-39y000z.cif
# Images to cif 223: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_-39x-347y000z.cif
# Images to cif 224: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_000x000y000z.cif
# Images to cif 225: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_381x-229y000z.cif
# Images to cif 226: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_163x018y000z.cif
# Images to cif 227: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_361x-347y000z.cif
# Images to cif 228: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-305x-052y000z.cif
# Images to cif 229: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_112x158y000z.cif
# Images to cif 230: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_-072x-242y000z.cif
# Images to cif 231: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_177x-179y000z.cif
# Images to cif 232: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-304x-198y000z.cif
# Images to cif 233: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-02x-052y000z.cif
# Images to cif 234: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_291x-285y000z.cif
# Images to cif 235: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-066x399y000z.cif
# Images to cif 236: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-091x-263y000z.cif
# Images to cif 237: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_393x357y000z.cif
# Images to cif 238: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_398x226y000z.cif
# Images to cif 239: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_000x000y000z.cif
# Images to cif 240: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_112x-116y000z.cif
# Images to cif 241: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-091x-229y000z.cif
# Images to cif 242: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_163x-38y000z.cif
# Images to cif 243: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_068x-179y000z.cif
# Images to cif 244: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_122x12y000z.cif
# Images to cif 245: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_000x000y000z.cif
# Images to cif 246: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-028x399y000z.cif
# Images to cif 247: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_112x232y000z.cif
# Images to cif 248: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_000x000y000z.cif
# Images to cif 249: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_-39x-377y000z.cif
# Images to cif 250: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-028x-133y000z.cif
# Images to cif 251: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_068x-242y000z.cif
# Images to cif 252: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_281x396y000z.cif
# Images to cif 253: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_209x-201y000z.cif
# Images to cif 254: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_281x-347y000z.cif
# Images to cif 255: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_-169x-116y000z.cif
# Images to cif 256: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_388x109y000z.cif
# Images to cif 257: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_393x031y000z.cif
# Images to cif 258: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-395x-133y000z.cif
# Images to cif 259: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_023x12y000z.cif
# Images to cif 260: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_361x396y000z.cif
# Images to cif 261: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-066x-133y000z.cif
# Images to cif 262: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-052x169y000z.cif
# Images to cif 263: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_16x039y000z.cif
# Images to cif 264: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_363x357y000z.cif
# Images to cif 265: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_-331x031y000z.cif
# Images to cif 266: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-02x-198y000z.cif
# Images to cif 267: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-052x-263y000z.cif
# Images to cif 268: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_159x211y000z.cif
# Images to cif 269: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_000x000y000z.cif
# Images to cif 270: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_398x-285y000z.cif
# Images to cif 271: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_-331x-109y000z.cif
# Images to cif 272: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_-331x357y000z.cif
# Images to cif 273: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_000x000y000z.cif
# Images to cif 274: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_068x-263y000z.cif
# Images to cif 275: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_000x000y000z.cif
# Images to cif 276: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-304x-052y000z.cif
# Images to cif 277: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_122x-254y000z.cif
# Images to cif 278: 10	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_291x-043y000z.cif
# Images to cif 279: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_163x109y000z.cif
# Images to cif 280: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_-033x-38y000z.cif
# Images to cif 281: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_129x-284y000z.cif
# Images to cif 282: 10	em_data/2at/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_-169x232y000z.cif
# Images to cif 283: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_381x169y000z.cif
# Images to cif 284: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_000x000y000z.cif
# Images to cif 285: 10	em_data/2at/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_361x-377y000z.cif
# Images to cif 286: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_000x000y000z.cif
# Images to cif 287: 0	em_data/2at/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_-019x039y000z.cif
# Images to cif 288: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_16x228y000z.cif
# Images to cif 289: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-304x-39y000z.cif
# Images to cif 290: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-091x169y000z.cif
# Images to cif 291: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_07x158y000z.cif
# Images to cif 292: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_-019x167y000z.cif
# Images to cif 293: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_177x-242y000z.cif
# Images to cif 294: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_-072x-263y000z.cif
# Images to cif 295: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_388x018y000z.cif
# Images to cif 296: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-066x-006y000z.cif
# Images to cif 297: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_-019x228y000z.cif
# Images to cif 298: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-305x-198y000z.cif
# Images to cif 299: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-395x-006y000z.cif
# Images to cif 300: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_000x000y000z.cif
# Images to cif 301: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_007x-254y000z.cif
# Images to cif 302: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_007x12y000z.cif
# Images to cif 303: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_388x-38y000z.cif
# Images to cif 304: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_129x211y000z.cif
# Images to cif 305: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-028x-006y000z.cif
# Images to cif 306: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_023x-254y000z.cif
# Images to cif 307: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_000x000y000z.cif
# Images to cif 308: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_393x-109y000z.cif
# Images to cif 309: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_122x362y000z.cif
# Images to cif 310: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_291x226y000z.cif
# Images to cif 311: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_07x232y000z.cif
# Images to cif 312: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_209x211y000z.cif
# Images to cif 313: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_129x-201y000z.cif
# Images to cif 314: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_398x-043y000z.cif
# Images to cif 315: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_-072x-179y000z.cif
# Images to cif 316: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_363x-109y000z.cif
# Images to cif 317: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_078x-285y000z.cif
# Images to cif 318: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_-169x158y000z.cif
# Images to cif 319: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_331x228y000z.cif
# Images to cif 320: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-395x399y000z.cif
# Images to cif 321: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_177x-263y000z.cif
# Images to cif 322: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-052x-229y000z.cif
# Images to cif 323: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_-033x109y000z.cif
# Images to cif 324: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_281x-377y000z.cif
# Images to cif 325: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_209x-284y000z.cif
# Images to cif 326: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_16x167y000z.cif
# Images to cif 327: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_-033x018y000z.cif
# Images to cif 328: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_159x-284y000z.cif
# Images to cif 329: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_159x-201y000z.cif
# Images to cif 330: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_381x-263y000z.cif
# Images to cif 331: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-305x-39y000z.cif
# Images to cif 332: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_-39x396y000z.cif
# Images to cif 333: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_000x000y000z.cif
# Images to cif 334: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_023x362y000z.cif
# Images to cif 335: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_007x362y000z.cif
# Images to cif 336: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_363x031y000z.cif
# Images to cif 337: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_331x167y000z.cif
# Images to cif 338: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_07x-116y000z.cif
# Images to cif 339: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_078x226y000z.cif
# Images to cif 340: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_078x-043y000z.cif
# Images to cif 341: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_331x039y000z.cif
# Images to cif 342: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-02x-39y000z.cif
# Images to cif 343: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_-39x-347y000z.cif
# Images to cif 344: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_000x000y000z.cif
# Images to cif 345: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_381x-229y000z.cif
# Images to cif 346: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_163x018y000z.cif
# Images to cif 347: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_361x-347y000z.cif
# Images to cif 348: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-305x-052y000z.cif
# Images to cif 349: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_112x158y000z.cif
# Images to cif 350: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_-072x-242y000z.cif
# Images to cif 351: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_177x-179y000z.cif
# Images to cif 352: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-304x-198y000z.cif
# Images to cif 353: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-02x-052y000z.cif
# Images to cif 354: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_291x-285y000z.cif
# Images to cif 355: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-066x399y000z.cif
# Images to cif 356: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-091x-263y000z.cif
# Images to cif 357: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_393x357y000z.cif
# Images to cif 358: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_398x226y000z.cif
# Images to cif 359: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_000x000y000z.cif
# Images to cif 360: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_112x-116y000z.cif
# Images to cif 361: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-091x-229y000z.cif
# Images to cif 362: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_163x-38y000z.cif
# Images to cif 363: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_068x-179y000z.cif
# Images to cif 364: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_122x12y000z.cif
# Images to cif 365: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_000x000y000z.cif
# Images to cif 366: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-028x399y000z.cif
# Images to cif 367: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_112x232y000z.cif
# Images to cif 368: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_000x000y000z.cif
# Images to cif 369: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_-39x-377y000z.cif
# Images to cif 370: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-028x-133y000z.cif
# Images to cif 371: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_068x-242y000z.cif
# Images to cif 372: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_281x396y000z.cif
# Images to cif 373: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_209x-201y000z.cif
# Images to cif 374: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_281x-347y000z.cif
# Images to cif 375: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_-169x-116y000z.cif
# Images to cif 376: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_388x109y000z.cif
# Images to cif 377: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_393x031y000z.cif
# Images to cif 378: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-395x-133y000z.cif
# Images to cif 379: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_023x12y000z.cif
# Images to cif 380: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_361x396y000z.cif
# Images to cif 381: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-1def_expanded_-066x-133y000z.cif
# Images to cif 382: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-052x169y000z.cif
# Images to cif 383: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_16x039y000z.cif
# Images to cif 384: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_363x357y000z.cif
# Images to cif 385: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_-331x031y000z.cif
# Images to cif 386: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-02x-198y000z.cif
# Images to cif 387: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_-052x-263y000z.cif
# Images to cif 388: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_159x211y000z.cif
# Images to cif 389: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_000x000y000z.cif
# Images to cif 390: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_398x-285y000z.cif
# Images to cif 391: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_-331x-109y000z.cif
# Images to cif 392: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-1def_expanded_-331x357y000z.cif
# Images to cif 393: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_000x000y000z.cif
# Images to cif 394: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-1def_expanded_068x-263y000z.cif
# Images to cif 395: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_000x000y000z.cif
# Images to cif 396: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_0-0def_expanded_-304x-052y000z.cif
# Images to cif 397: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_0-0def_expanded_122x-254y000z.cif
# Images to cif 398: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_0-0def_expanded_291x-043y000z.cif
# Images to cif 399: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_163x109y000z.cif
# Images to cif 400: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_2-2def_expanded_-033x-38y000z.cif
# Images to cif 401: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_129x-284y000z.cif
# Images to cif 402: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_2mu_1-2def_expanded_-169x232y000z.cif
# Images to cif 403: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_2-2def_expanded_381x169y000z.cif
# Images to cif 404: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_000x000y000z.cif
# Images to cif 405: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_sawtooh_2mu_1-2def_expanded_361x-377y000z.cif
# Images to cif 406: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_2-2def_expanded_000x000y000z.cif
# Images to cif 407: 10	em_data/2at_2/CIF/CeO2_[110]_110sur_step_2mu_1-2def_expanded_-019x039y000z.cif
# Images to cif 408: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_0-0def_expanded_-05x-22y000z.cif
# Images to cif 409: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-1def_expanded_-322x294y000z.cif
# Images to cif 410: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-2def_expanded_298x-069y000z.cif
# Images to cif 411: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_2-2def_expanded_172x193y000z.cif
# Images to cif 412: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_0-0def_expanded_176x107y000z.cif
# Images to cif 413: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_2-2def_expanded_000x000y000z.cif
# Images to cif 414: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-2def_expanded_-322x113y000z.cif
# Images to cif 415: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-1def_expanded_101x272y000z.cif
# Images to cif 416: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-1def_expanded_-39x-163y000z.cif
# Images to cif 417: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-1def_expanded_000x000y000z.cif
# Images to cif 418: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-1def_expanded_328x-182y000z.cif
# Images to cif 419: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-1def_expanded_237x294y000z.cif
# Images to cif 420: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-2def_expanded_157x012y000z.cif
# Images to cif 421: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-1def_expanded_-095x133y000z.cif
# Images to cif 422: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-0def_expanded_105x-245y000z.cif
# Images to cif 423: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-1def_expanded_-245x294y000z.cif
# Images to cif 424: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_2-2def_expanded_226x063y000z.cif
# Images to cif 425: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-1def_expanded_053x133y000z.cif
# Images to cif 426: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-2def_expanded_174x228y000z.cif
# Images to cif 427: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-1def_expanded_135x-182y000z.cif
# Images to cif 428: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_2-2def_expanded_023x341y000z.cif
# Images to cif 429: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-1def_expanded_-39x272y000z.cif
# Images to cif 430: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-1def_expanded_-361x-163y000z.cif
# Images to cif 431: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-1def_expanded_101x309y000z.cif
# Images to cif 432: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-1def_expanded_237x-266y000z.cif
# Images to cif 433: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_2-2def_expanded_172x-389y000z.cif
# Images to cif 434: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-1def_expanded_-322x-266y000z.cif
# Images to cif 435: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-2def_expanded_-322x012y000z.cif
# Images to cif 436: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-0def_expanded_105x-345y000z.cif
# Images to cif 437: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-0def_expanded_000x000y000z.cif
# Images to cif 438: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-2def_expanded_174x-023y000z.cif
# Images to cif 439: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-2def_expanded_349x-069y000z.cif
# Images to cif 440: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-0def_expanded_-059x-245y000z.cif
# Images to cif 441: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-1def_expanded_-245x329y000z.cif
# Images to cif 442: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_2-2def_expanded_-183x-389y000z.cif
# Images to cif 443: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-1def_expanded_04x-109y000z.cif
# Images to cif 444: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-1def_expanded_-361x272y000z.cif
# Images to cif 445: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_0-0def_expanded_000x000y000z.cif
# Images to cif 446: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-2def_expanded_349x385y000z.cif
# Images to cif 447: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-2def_expanded_174x39y000z.cif
# Images to cif 448: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-2def_expanded_245x39y000z.cif
# Images to cif 449: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-1def_expanded_053x-362y000z.cif
# Images to cif 450: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-1def_expanded_04x-014y000z.cif
# Images to cif 451: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-2def_expanded_298x-354y000z.cif
# Images to cif 452: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-2def_expanded_000x000y000z.cif
# Images to cif 453: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-1def_expanded_-095x049y000z.cif
# Images to cif 454: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_2-2def_expanded_226x341y000z.cif
# Images to cif 455: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_0-0def_expanded_-319x-382y000z.cif
# Images to cif 456: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_2-2def_expanded_-109x193y000z.cif
# Images to cif 457: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_2-2def_expanded_000x000y000z.cif
# Images to cif 458: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-1def_expanded_237x329y000z.cif
# Images to cif 459: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-2def_expanded_004x385y000z.cif
# Images to cif 460: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-0def_expanded_-059x-345y000z.cif
# Images to cif 461: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_2-2def_expanded_023x068y000z.cif
# Images to cif 462: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_0-0def_expanded_102x-183y000z.cif
# Images to cif 463: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_0-0def_expanded_054x-183y000z.cif
# Images to cif 464: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_0-0def_expanded_176x-382y000z.cif
# Images to cif 465: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-2def_expanded_000x000y000z.cif
# Images to cif 466: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-2def_expanded_157x104y000z.cif
# Images to cif 467: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_0-0def_expanded_054x-22y000z.cif
# Images to cif 468: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_2-2def_expanded_023x063y000z.cif
# Images to cif 469: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-1def_expanded_101x-163y000z.cif
# Images to cif 470: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-2def_expanded_035x012y000z.cif
# Images to cif 471: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-1def_expanded_135x-014y000z.cif
# Images to cif 472: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_1-2def_expanded_004x-069y000z.cif
# Images to cif 473: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-1def_expanded_04x-182y000z.cif
# Images to cif 474: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_2-2def_expanded_172x-336y000z.cif
# Images to cif 475: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-1def_expanded_000x000y000z.cif
# Images to cif 476: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_2-2def_expanded_-109x-336y000z.cif
# Images to cif 477: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_0-0def_expanded_109x-382y000z.cif
# Images to cif 478: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-0def_expanded_196x-245y000z.cif
# Images to cif 479: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-2def_expanded_000x000y000z.cif
# Images to cif 480: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-2def_expanded_-322x104y000z.cif
# Images to cif 481: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_0-0def_expanded_109x107y000z.cif
# Images to cif 482: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_0-0def_expanded_-319x107y000z.cif
# Images to cif 483: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-2def_expanded_334x-023y000z.cif
# Images to cif 484: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-0def_expanded_196x-392y000z.cif
# Images to cif 485: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-1def_expanded_328x-109y000z.cif
# Images to cif 486: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-0def_expanded_105x-392y000z.cif
# Images to cif 487: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-2def_expanded_157x113y000z.cif
# Images to cif 488: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_0-0def_expanded_-319x-008y000z.cif
# Images to cif 489: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_2-2def_expanded_009x068y000z.cif
# Images to cif 490: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_2-2def_expanded_009x063y000z.cif
# Images to cif 491: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_0-0def_expanded_102x-22y000z.cif
# Images to cif 492: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-0def_expanded_196x-345y000z.cif
# Images to cif 493: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_2-2def_expanded_-109x-389y000z.cif
# Images to cif 494: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-0def_expanded_-059x-392y000z.cif
# Images to cif 495: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-1def_expanded_-095x-362y000z.cif
# Images to cif 496: 0	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_2-2def_expanded_-183x-336y000z.cif
# Images to cif 497: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_0-0def_expanded_000x000y000z.cif
# Images to cif 498: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_0-0def_expanded_-05x-183y000z.cif
# Images to cif 499: 10	em_data/3at/CIF/CeO2_[110]_110sur_step_3mu_0-0def_expanded_176x-008y000z.cif
# Images to cif 500: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-2def_expanded_245x228y000z.cif
# Images to cif 501: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-1def_expanded_000x000y000z.cif
# Images to cif 502: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-1def_expanded_000x000y000z.cif
# Images to cif 503: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-1def_expanded_-361x309y000z.cif
# Images to cif 504: 10	em_data/3at/CIF/CeO2_[110]_110sur_sawtooh_3mu_1-1def_expanded_-39x309y000z.cif
# Images to cif 505: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_0-1def_expanded_135x-109y000z.cif
# Images to cif 506: 10	em_data/3at/CIF/CeO2_[110]_110sur_3mu_1-1def_expanded_053x049y000z.cif
# ...
# Images to cif 2174: 0	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_138x302y000z.cif
# Images to cif 2175: 10	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_000x000y000z.cif
# Images to cif 2176: 10	em_data/10at/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_-243x287y000z.cif
# Images to cif 2177: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_126x-232y000z.cif
# Images to cif 2178: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_112x-232y000z.cif
# Images to cif 2179: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_264x102y000z.cif
# Images to cif 2180: 10	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_093x117y000z.cif
# Images to cif 2181: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_182x327y000z.cif
# Images to cif 2182: 10	em_data/10at/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_-334x287y000z.cif
# Images to cif 2183: 10	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_-346x178y000z.cif
# Images to cif 2184: 10	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_-289x178y000z.cif
# Images to cif 2185: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_-182x102y000z.cif
# Images to cif 2186: 0	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_289x302y000z.cif
# Images to cif 2187: 10	em_data/10at/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_197x-387y000z.cif
# Images to cif 2188: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_103x-133y000z.cif
# Images to cif 2189: 10	em_data/10at/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_186x041y000z.cif
# Images to cif 2190: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_287x327y000z.cif
# Images to cif 2191: 0	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_261x393y000z.cif
# Images to cif 2192: 10	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_-243x-053y000z.cif
# Images to cif 2193: 10	em_data/10at/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_197x-373y000z.cif
# Images to cif 2194: 10	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_000x000y000z.cif
# Images to cif 2195: 10	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_093x178y000z.cif
# Images to cif 2196: 10	em_data/10at/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_102x-365y000z.cif
# Images to cif 2197: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_103x-32y000z.cif
# Images to cif 2198: 0	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_261x-182y000z.cif
# Images to cif 2199: 0	em_data/10at/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_-057x-365y000z.cif
# Images to cif 2200: 10	em_data/10at/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_102x-16y000z.cif
# Images to cif 2201: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_-131x-033y000z.cif
# Images to cif 2202: 10	em_data/10at/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_-352x-104y000z.cif
# Images to cif 2203: 10	em_data/10at/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_-208x041y000z.cif
# Images to cif 2204: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_-398x-232y000z.cif
# Images to cif 2205: 0	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_-13x-046y000z.cif
# Images to cif 2206: 10	em_data/10at/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_-289x117y000z.cif
# Images to cif 2207: 10	em_data/10at/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_-182x399y000z.cif
# Images to cif 2208: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_000x000y000z.cif
# Images to cif 2209: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_-13x-182y000z.cif
# Images to cif 2210: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_-243x242y000z.cif
# Images to cif 2211: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_18x242y000z.cif
# Images to cif 2212: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_233x-033y000z.cif
# Images to cif 2213: 0	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_-352x-373y000z.cif
# Images to cif 2214: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_18x287y000z.cif
# Images to cif 2215: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_-077x-033y000z.cif
# Images to cif 2216: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_-131x115y000z.cif
# Images to cif 2217: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_038x302y000z.cif
# Images to cif 2218: 0	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_231x-104y000z.cif
# Images to cif 2219: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_233x-16y000z.cif
# Images to cif 2220: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_-114x-349y000z.cif
# Images to cif 2221: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_-057x-16y000z.cif
# Images to cif 2222: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_-127x-053y000z.cif
# Images to cif 2223: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_-114x041y000z.cif
# Images to cif 2224: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_112x-022y000z.cif
# Images to cif 2225: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_-398x226y000z.cif
# Images to cif 2226: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_-077x115y000z.cif
# Images to cif 2227: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_186x-008y000z.cif
# Images to cif 2228: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_-365x399y000z.cif
# Images to cif 2229: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_-182x072y000z.cif
# Images to cif 2230: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_000x000y000z.cif
# Images to cif 2231: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_112x226y000z.cif
# Images to cif 2232: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_182x-32y000z.cif
# Images to cif 2233: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_138x-141y000z.cif
# Images to cif 2234: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_283x362y000z.cif
# Images to cif 2235: 0	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_233x-365y000z.cif
# Images to cif 2236: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_-127x139y000z.cif
# Images to cif 2237: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_054x-182y000z.cif
# Images to cif 2238: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_-243x027y000z.cif
# Images to cif 2239: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_-352x-387y000z.cif
# Images to cif 2240: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_000x000y000z.cif
# Images to cif 2241: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_138x279y000z.cif
# Images to cif 2242: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_-243x-159y000z.cif
# Images to cif 2243: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_038x-141y000z.cif
# Images to cif 2244: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_102x-033y000z.cif
# Images to cif 2245: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_054x393y000z.cif
# Images to cif 2246: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_231x-387y000z.cif
# Images to cif 2247: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_-334x242y000z.cif
# Images to cif 2248: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_-365x102y000z.cif
# Images to cif 2249: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_289x-141y000z.cif
# Images to cif 2250: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_000x000y000z.cif
# Images to cif 2251: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_283x115y000z.cif
# Images to cif 2252: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_287x-32y000z.cif
# Images to cif 2253: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_000x000y000z.cif
# Images to cif 2254: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_-114x-008y000z.cif
# Images to cif 2255: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_-398x-022y000z.cif
# Images to cif 2256: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_287x-133y000z.cif
# Images to cif 2257: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_-334x027y000z.cif
# Images to cif 2258: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_-178x139y000z.cif
# Images to cif 2259: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_-13x393y000z.cif
# Images to cif 2260: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_264x399y000z.cif
# Images to cif 2261: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_-346x117y000z.cif
# Images to cif 2262: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_-289x-169y000z.cif
# Images to cif 2263: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_-077x362y000z.cif
# Images to cif 2264: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_126x-022y000z.cif
# Images to cif 2265: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_-178x-053y000z.cif
# Images to cif 2266: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_-243x139y000z.cif
# Images to cif 2267: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_093x-169y000z.cif
# Images to cif 2268: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_-131x362y000z.cif
# Images to cif 2269: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_000x000y000z.cif
# Images to cif 2270: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_264x072y000z.cif
# Images to cif 2271: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_18x027y000z.cif
# Images to cif 2272: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_261x-046y000z.cif
# Images to cif 2273: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_103x327y000z.cif
# Images to cif 2274: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_-346x-169y000z.cif
# Images to cif 2275: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_000x000y000z.cif
# Images to cif 2276: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_289x279y000z.cif
# Images to cif 2277: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_283x-033y000z.cif
# Images to cif 2278: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_-208x-008y000z.cif
# Images to cif 2279: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_186x-349y000z.cif
# Images to cif 2280: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_000x000y000z.cif
# Images to cif 2281: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_182x-133y000z.cif
# Images to cif 2282: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_054x-046y000z.cif
# Images to cif 2283: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_-365x072y000z.cif
# Images to cif 2284: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_038x279y000z.cif
# Images to cif 2285: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_000x000y000z.cif
# Images to cif 2286: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_197x-104y000z.cif
# Images to cif 2287: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_-057x-033y000z.cif
# Images to cif 2288: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_-178x-159y000z.cif
# Images to cif 2289: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_000x000y000z.cif
# Images to cif 2290: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_-127x-159y000z.cif
# Images to cif 2291: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_126x226y000z.cif
# Images to cif 2292: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_-208x-349y000z.cif
# Images to cif 2293: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_231x-373y000z.cif
# Images to cif 2294: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_138x302y000z.cif
# Images to cif 2295: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_000x000y000z.cif
# Images to cif 2296: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_-243x287y000z.cif
# Images to cif 2297: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_126x-232y000z.cif
# Images to cif 2298: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_112x-232y000z.cif
# Images to cif 2299: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_264x102y000z.cif
# Images to cif 2300: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_093x117y000z.cif
# Images to cif 2301: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_182x327y000z.cif
# Images to cif 2302: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_2-2def_expanded_-334x287y000z.cif
# Images to cif 2303: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_-346x178y000z.cif
# Images to cif 2304: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_-289x178y000z.cif
# Images to cif 2305: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_-182x102y000z.cif
# Images to cif 2306: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_2-2def_expanded_289x302y000z.cif
# Images to cif 2307: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_197x-387y000z.cif
# Images to cif 2308: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_103x-133y000z.cif
# Images to cif 2309: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_186x041y000z.cif
# Images to cif 2310: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_287x327y000z.cif
# Images to cif 2311: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_261x393y000z.cif
# Images to cif 2312: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-1def_expanded_-243x-053y000z.cif
# Images to cif 2313: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_197x-373y000z.cif
# Images to cif 2314: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_000x000y000z.cif
# Images to cif 2315: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_093x178y000z.cif
# Images to cif 2316: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_102x-365y000z.cif
# Images to cif 2317: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_2-2def_expanded_103x-32y000z.cif
# Images to cif 2318: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_261x-182y000z.cif
# Images to cif 2319: 0	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_-057x-365y000z.cif
# Images to cif 2320: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_0-0def_expanded_102x-16y000z.cif
# Images to cif 2321: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-1def_expanded_-131x-033y000z.cif
# Images to cif 2322: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-2def_expanded_-352x-104y000z.cif
# Images to cif 2323: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_10mu_1-1def_expanded_-208x041y000z.cif
# Images to cif 2324: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_1-2def_expanded_-398x-232y000z.cif
# Images to cif 2325: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_1-2def_expanded_-13x-046y000z.cif
# Images to cif 2326: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_step_10mu_0-0def_expanded_-289x117y000z.cif
# Images to cif 2327: 10	em_data/10at_2/CIF/CeO2_[110]_110sur_sawtooh_10mu_0-0def_expanded_-182x399y000z.cif

# %%
len(defocus_list)
# Out:
# 21117

# %%
import pickle

with open("X_list_full.pkl", "wb") as fp:   #Pickling
    pickle.dump(X_list, fp)

with open("y_list_full.pkl", "wb") as fp:   #Pickling
    pickle.dump(y_list, fp)

with open("defocus_list_full.pkl", "wb") as fp:   #Pickling
    pickle.dump(defocus_list, fp)

with open("img_file_list_full.pkl", "wb") as fp:   #Pickling
    pickle.dump(img_file_list, fp)

# %%
def last_filled_slice(grid):
    '''Function returns index of the last non-zero slice in the grid.'''
    # Sum the x-y slices
    slice_sums = grid.sum(axis=0).sum(axis=0)
    # Identify the last non-zero slice
    idx = max(index for index, item in enumerate(slice_sums) if item > 0)
    return idx

# %%
def count_training_data(dir_header, dir_list_cif, dir_list_img,defocus_used):
    '''
    Generates pairs of voxel grid (X) and image (y) as well as defocus parameter and filenames, for training
    3D grid -> image model.
    
    Inputs:
    dir_list_cif - list of directories containing .cif files, relative path from current directory
    dir_list_img - list of directories containing .yif files, relative path from current directory
    voxel_count - scalar int indicating desired voxels per grid dimension
    atoms_used - List of strings indicating which atom types (e.g. ['O', 'Ce']) to include. 
    defocus_used - List of ints indicating which defocus values to include. If set to 1, all values are used.
    im_size - 2-tuple of ints indicating desired pixels per image dimension (X,Y)
    
    Outputs:
    X_list - List of [grid, atom_type] lists for each .cif-.tif pair used. 
              grid is a [voxel_size^3] np.array with counts of atoms in each voxel
              atom_type is a np.array of strings for each atom's periodic symbol
                
    y_list - List of images, one for each entry in X_list. image is a [im_size[0],im_size[1]] np.array of pixel values.
              image created by cropping input to square then resizing to im_size in PIL.
    defocus_list - List of ints, defocus parameter for each sample 
    img_file_list - List of image filenames for each sample.
    
    '''
    cif_files = []
    for dirr in dir_list_cif:
        cif_files.extend(glob.glob(dir_header+dirr+'/Ce*.cif'))

    cif_count = 0
    cif_image_count = []
    image_count = 0
    for cif in cif_files:
        # count the cif files
        cif_count +=1
        # Find all associated images
        img_files = []
        [img_files.extend(glob.glob((dir_header+dirr+cif[cif.find("/",len(dir_header)+5):-4]+'*.tif').replace('[','?').replace(']','?'))) for dirr in dir_list_img]
        # find starts after the dir_header so it catches the last /
        # Filter out 'def' files
        img_files_clean = []
        for i,im_f in enumerate(img_files):
            if im_f.find("_def_") < 0:
                img_files_clean.append(im_f)
        img_files = img_files_clean

        # Filter by Defocus value
        nm_loc = [im_f.find("nmDefocus") for im_f in img_files]
        
#         defocus_cif = [abs(int(im_f[loc-2:loc])) for im_f,loc in zip(img_files,nm_loc)]
        defocus_cif = []
        for im_f,loc in zip(img_files,nm_loc):
            if im_f[loc-2:loc-1] == '_':
                defocus_cif.append(abs(int(im_f[loc-1:loc])))
            else:
                defocus_cif.append(abs(int(im_f[loc-2:loc])))
            
    
        if defocus_used == 1:
            defocus_used = set(defocus_cif)
            
        cif_image_count.append(len(defocus_used))
        image_count += len(defocus_used)
    return cif_count, cif_image_count, image_count

# %%
cif_count, cif_image_count, image_count = count_training_data(dir_header, dir_list_cif, dir_list_img,defocus_used)

# %%
print(".cif count: ",cif_count)
print("image_count: ",image_count)

# %%
defocus_list
